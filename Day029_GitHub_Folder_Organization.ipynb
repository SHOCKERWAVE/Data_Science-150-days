# %%
#SQL_Basics/
#│── 21_SQL_SELECT/
#│   │── Day021_SQL_SELECT.ipynb
#│   │── day21.db
#│   └── README.md
#│── 22_SQL_WHERE_ORDERBY/
#│   │── Day022_SQL_WHERE_ORDERBY.ipynb
#│   │── day22.db
#│   └── README.md
#│── 23_SQL_JOINS/
#│   │── Day023_SQL_JOINS.ipynb
#│   │── day23.db
#│   └── README.md
#│── 24_SQL_GROUPBY_HAVING/
#│   │── Day024_SQL_GROUPBY_HAVING.ipynb
#│   │── day24.db
#│   └── README.md
#│── 25_SQL_Practice_Project/
#│   │── Day025_SQL_Practice_Project.ipynb
#│   │── day25.db
#│   └── README.md

# %%
#DataScience_Roadmap/
#│── Phase1_Foundations/
#│   └── 01_Python_Variables/
#│   └── 02_Python_Lists/
#│   └── ...
#│── Phase2_MachineLearning/
#│   └── 31_LinearRegression_Theory/
#│   └── 32_LinearRegression_Code/
#│   └── ...
#│── Phase3_DeepLearning/
#│── Phase4_BI_Dashboards/
#│── Phase5_Portfolio_Deployment/
#└── README.md   (main roadmap summary)
