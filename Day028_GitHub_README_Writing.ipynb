# %%
# Project Title
#Short description of the project.

## Features
#- What the project does
#- Why it’s useful

## Installation
#Steps to run the project locally.

## Usage
#Examples of how to use it.

## Results
#Screenshots, outputs, or summary.

## Contributing
#(Optional) How others can contribute.

## License
#(Optional) License details.

# %%
# SQL Practice Project

## Overview
#This project demonstrates SQL basics including SELECT, WHERE, ORDER BY, JOIN, GROUP BY, and HAVING.

## Features
#- Employee + Department tables
#- Queries for filtering, sorting, joining, and grouping
#- Practice exercises included

## How to Run
#1. Clone the repo
#2. Open `Day025_SQL_Practice_Project.ipynb`
#3. Run queries in Jupyter Notebook

## Results
#- Average salary per department
#- Departments with >2 employees
#- Top 3 highest paid employees
