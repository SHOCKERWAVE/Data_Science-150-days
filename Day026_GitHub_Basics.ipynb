# %%
# Check if Git is installed
#git --version

# If not installed (Windows), download from: https://git-scm.com/downloads

# %%
# Set your GitHub username
#git config --global user.name "ShubhamSingh"

# Set your GitHub email (same as GitHub account)
#git config --global user.email "your_email@example.com"

# %%
# Copy the HTTPS link from GitHub repo
#git clone https://github.com/YourUsername/DataScience_Roadmap.git

# Move into repo folder
#cd DataScience_Roadmap

# %%
# List files inside repo
#ls
