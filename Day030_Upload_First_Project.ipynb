# %%
#Phase1_Foundations/
#│── 25_SQL_Practice_Project/
#│   │── Day025_SQL_Practice_Project.ipynb
#│   │── day25.db
#│   └── README.md

# %%
#git add Phase1_Foundations/25_SQL_Practice_Project/*

# %%
#git commit -m "Uploaded Day 25 SQL Practice Project"

# %%
#git push origin main
